# %% [markdown]
# # The Elbow Method

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the Data

# %%
data = pd.read_csv('/content/3.01. Country clusters.csv')
data.head()
# Out:
#    Country  Latitude  Longitude Language
# 0      USA     44.97    -103.77  English
# 1   Canada     62.40     -96.80  English
# 2   France     46.75       2.40   French
# 3       UK     54.01      -2.53  English
# 4  Germany     51.15      10.40   German

# %% [markdown]
# ## Map the Data

# %%
data_mapped = data.copy()
data_mapped['Language']= data_mapped['Language'].map({'English':0, 'French':1, 'German':2})
data_mapped
# Out:
#      Country  Latitude  Longitude  Language
# 0        USA     44.97    -103.77         0
# 1     Canada     62.40     -96.80         0
# 2     France     46.75       2.40         1
# 3         UK     54.01      -2.53         0
# 4    Germany     51.15      10.40         2
# 5  Australia    -25.45     133.11         0

# %% [markdown]
# ##Select the Featurs

# %%
x = data_mapped.iloc[:, 1:4]
x
# Out:
#    Latitude  Longitude  Language
# 0     44.97    -103.77         0
# 1     62.40     -96.80         0
# 2     46.75       2.40         1
# 3     54.01      -2.53         0
# 4     51.15      10.40         2
# 5    -25.45     133.11         0

# %% [markdown]
# ## Clusterinng

# %%
kmeans = KMeans(2)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# ## Clustering the results

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([0, 0, 0, 0, 0, 1], dtype=int32)

# %%
data_with_clusters = data_mapped.copy()
data_with_clusters['Cluster'] = identified_clusters
data_with_clusters
# Out:
#      Country  Latitude  Longitude  Language  Cluster
# 0        USA     44.97    -103.77         0        0
# 1     Canada     62.40     -96.80         0        0
# 2     France     46.75       2.40         1        0
# 3         UK     54.01      -2.53         0        0
# 4    Germany     51.15      10.40         2        0
# 5  Australia    -25.45     133.11         0        1

# %%
plt.scatter(data_with_clusters['Longitude'], data_with_clusters['Latitude'], c=data_with_clusters['Cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# # Selecting the number of clusters

# %% [markdown]
# ## WCSS

# %%
kmeans.inertia_
# Out:
# 13208.958119999996

# %% [markdown]
# - **list.append(x)** : appends a new item with the value x to the end of the object

# %%
wcss=[]

for i in range(1,7):
  kmeans = KMeans(i)
  kmeans.fit(x)
  wcss_iter = kmeans.inertia_
  wcss.append(wcss_iter)

# %% [markdown]
# The sequence is decreasin with very big leaps in the first two steps

# %%
wcss
# Out:
# [42605.41356666667,
#  17246.714500000002,
#  290.10523333333333,
#  113.91233333333332,
#  39.00624999999998,
#  0.0]

# %% [markdown]
# ## The Elbow Method

# %%
number_clusters = range(1,7)
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# A two cluster solution would be suboptimal as the leap from 2 to 3 is very big
